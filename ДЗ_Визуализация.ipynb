# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 11,7 ## дюймы

# %%
df = pd.read_csv('Players.csv')
print(df.shape)
df.head()
# Out:
# (3922, 8)
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3922 entries, 0 to 3921
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3922 non-null   int64
#  1   Player       3921 non-null   object
#  2   height       3921 non-null   float64
#  3   weight       3921 non-null   float64
#  4   collage      3573 non-null   object
#  5   born         3921 non-null   float64
#  6   birth_city   3452 non-null   object
#  7   birth_state  3439 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 245.2+ KB

# %%
# График №1, показывающий распределение игроков по росту и весу
plt.scatter(df['height'], df['weight'])
plt.xlabel('Рост игроков')
plt.ylabel('Вес игроков')
plt.show()

# %%
df_2 = pd.read_csv('player_data.csv')
print(df_2.shape)
df_2.head(10)
#count = df_2['birth_date'].value_counts()
#print(count)

missing_data = df_2['birth_date'].notnull()
#missing_data.head(10)
# Out:
# (4550, 8)

# %%
print(df_2['birth_date'][0])
# Out:
# June 24, 1968

# %%
date_time_str = df_2['birth_date'][0]
date_time_obj = datetime.datetime.strptime(date_time_str, '%B %d, %Y')
print(date_time_obj)
# Out:
# 1968-06-24 00:00:00

# %%
from numpy.ma.core import tan
time_massive = []

for i in range(4550):
  date_time_str = df_2['birth_date'][i]
  #date_time_obj = datetime.datetime.strptime(date_time_str, '%B %d, %Y')
  #time_massive.append(date_time_obj)
  date_time_obj = datetime.datetime.strptime(date_time_str, '%B %d, %Y')
  date_element = date_time_obj.strftime('%m')
  time_massive.append(date_element)
#print(time_massive)

df_2['birth_date'] = time_massive
y = df_2['birth_date'].value_counts()
pd.DataFrame(y)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-0b964f8f222e> in <cell line: 4>()
#       6   #date_time_obj = datetime.datetime.strptime(date_time_str, '%B %d, %Y')
#       7   #time_massive.append(date_time_obj)
# ----> 8   date_time_obj = datetime.datetime.strptime(date_time_str, '%B %d, %Y')
#       9   date_element = date_time_obj.strftime('%m')
#      10   time_massive.append(date_element)
#
# TypeError: strptime() argument 1 must be str, not float

# %%
time_massive.groupby(month).size().plot.bar(rot=90, grid=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-8d59d61f4b9d> in <cell line: 1>()
# ----> 1 time_massive.groupby(month).size().plot.bar(rot=90, grid=True)
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
df_3 = pd.read_csv('Seasons_Stats.csv')
print(df_3.shape)
df_3.head()
# Out:
# (24691, 53)
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]
